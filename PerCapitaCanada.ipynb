# %%
import pandas as pd
import matplotlib.pylab as plt

# %%
data=pd.read_csv('canada_per_capita_income.csv',sep=',')
data.columns=['YEAR','PER CAPITA INCOME']
data
# Out:
#     YEAR  PER CAPITA INCOME
# 0   1970        3399.299037
# 1   1971        3768.297935
# 2   1972        4251.175484
# 3   1973        4804.463248
# 4   1974        5576.514583
# 5   1975        5998.144346
# 6   1976        7062.131392
# 7   1977        7100.126170
# 8   1978        7247.967035
# 9   1979        7602.912681
# 10  1980        8355.968120
# 11  1981        9434.390652
# 12  1982        9619.438377
# 13  1983       10416.536590
# 14  1984       10790.328720
# 15  1985       11018.955850
# 16  1986       11482.891530
# 17  1987       12974.806620
# 18  1988       15080.283450
# 19  1989       16426.725480
# 20  1990       16838.673200
# 21  1991       17266.097690
# 22  1992       16412.083090
# 23  1993       15875.586730
# 24  1994       15755.820270
# 25  1995       16369.317250
# 26  1996       16699.826680
# 27  1997       17310.757750
# 28  1998       16622.671870
# 29  1999       17581.024140
# 30  2000       18987.382410
# 31  2001       18601.397240
# ...

# %%
fig, ax = plt.subplots(figsize=(8, 4))
#plt.plot(data['YEAR'], data['PER CAPITA INCOME'])
ax.plot(data['YEAR'], data['PER CAPITA INCOME'], marker='o', label='Per Capita Income')
ax.grid(True, linestyle='-', alpha=0.5)

plt.xlabel('Year')
plt.ylabel('Per Capita Income')
plt.title('Per Capita Income in Canada Over the Years')
plt.show()

# %% [markdown]
# **Checking for Null Values in the Dataset**

# %%
data[data['PER CAPITA INCOME'].isnull()]
# Out:
# Empty DataFrame
# Columns: [YEAR, PER CAPITA INCOME]
# Index: []

# %%
data[data['PER CAPITA INCOME'].notnull()].head()
# Out:
#    YEAR  PER CAPITA INCOME
# 0  1970        3399.299037
# 1  1971        3768.297935
# 2  1972        4251.175484
# 3  1973        4804.463248
# 4  1974        5576.514583

# %% [markdown]
# **Finding Median Value of Per Capita Income (Dependent Value)**

# %%
y_med=data['PER CAPITA INCOME'].median()
print("Median Value of the Dataset : ",y_med)
# Out:
# Median Value of the Dataset :  16426.72548

# %% [markdown]
# **Filtering the Dataset**
#
# dropna and fillna are two methods that are used to deal with missing data in DataFrames.
#
# dropna removes rows or columns that contain missing values. This can be useful if you want to focus on the data that is complete, or if you want to remove the rows or columns that are likely to be inaccurate due to the missing values.
#
# fillna replaces missing values with a specified value. This can be useful if you want to retain all of the data, or if you want to estimate the missing values based on the existing data.
#
#
#
# > Impute the missing values. This is another option which is more complex, but it can be more accurate than simply replacing the missing values with a constant value. Imputation involves estimating the missing values based on the existing data. There are several different imputation methods available, such as mean imputation, median imputation, and multiple imputation.

# %%
dropfilter=data.dropna(how='any',axis=0)
dropfilter
# Out:
#     YEAR  PER CAPITA INCOME
# 0   1970        3399.299037
# 1   1971        3768.297935
# 2   1972        4251.175484
# 3   1973        4804.463248
# 4   1974        5576.514583
# 5   1975        5998.144346
# 6   1976        7062.131392
# 7   1977        7100.126170
# 8   1978        7247.967035
# 9   1979        7602.912681
# 10  1980        8355.968120
# 11  1981        9434.390652
# 12  1982        9619.438377
# 13  1983       10416.536590
# 14  1984       10790.328720
# 15  1985       11018.955850
# 16  1986       11482.891530
# 17  1987       12974.806620
# 18  1988       15080.283450
# 19  1989       16426.725480
# 20  1990       16838.673200
# 21  1991       17266.097690
# 22  1992       16412.083090
# 23  1993       15875.586730
# 24  1994       15755.820270
# 25  1995       16369.317250
# 26  1996       16699.826680
# 27  1997       17310.757750
# 28  1998       16622.671870
# 29  1999       17581.024140
# 30  2000       18987.382410
# 31  2001       18601.397240
# ...

# %%
fillfilter=data.fillna(value=y_med)
fillfilter
# Out:
#     YEAR  PER CAPITA INCOME
# 0   1970        3399.299037
# 1   1971        3768.297935
# 2   1972        4251.175484
# 3   1973        4804.463248
# 4   1974        5576.514583
# 5   1975        5998.144346
# 6   1976        7062.131392
# 7   1977        7100.126170
# 8   1978        7247.967035
# 9   1979        7602.912681
# 10  1980        8355.968120
# 11  1981        9434.390652
# 12  1982        9619.438377
# 13  1983       10416.536590
# 14  1984       10790.328720
# 15  1985       11018.955850
# 16  1986       11482.891530
# 17  1987       12974.806620
# 18  1988       15080.283450
# 19  1989       16426.725480
# 20  1990       16838.673200
# 21  1991       17266.097690
# 22  1992       16412.083090
# 23  1993       15875.586730
# 24  1994       15755.820270
# 25  1995       16369.317250
# 26  1996       16699.826680
# 27  1997       17310.757750
# 28  1998       16622.671870
# 29  1999       17581.024140
# 30  2000       18987.382410
# 31  2001       18601.397240
# ...

# %% [markdown]
# **Approaches that can be used for model building**
#
# - Linear Regression
# - Multiple Linear Regression
# - Sparse Model
# - Logistic Regression
# - K Nearest Neighbour

# %% [markdown]
# # **LINEAR REGRESSION**
#
#
# Linear regression is a supervised machine learning algorithm that predicts a continuous value (such as a price or a score) based on a set of independent variables. It does this by fitting a straight line to the data, such that the line minimizes the distance between the line and the data points.
#
# The independent variables are the features that are used to predict the dependent variable. For example, if you are trying to predict the price of a house, the independent variables might be the size of the house, the number of bedrooms, the location, and the age of the house.
#
# The dependent variable is the value that you are trying to predict. In the example of predicting the price of a house, the dependent variable would be the price of the house.
#
# The line that is fit to the data is called the regression line. The slope of the regression line indicates the relationship between the independent and dependent variables. For example, if the slope is positive, then the dependent variable increases as the independent variable increases. If the slope is negative, then the dependent variable decreases as the independent variable increases.
#
#
# These are some ways of how linear regression can be used:
#
# - Predicting the price of a house
#
# - Predicting the demand for a product
#
# - Predicting the success of a marketing campaign
#
# - Predicting the risk of a disease
#
# - Predicting the time it takes to complete a task

# %% [markdown]
# **Building the Model**
#
#
# > Regression Model

# %%
from sklearn.linear_model import LinearRegression
est=LinearRegression(fit_intercept=True)

# %%
x=dropfilter[['YEAR']]
y=dropfilter[['PER CAPITA INCOME']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.2,random_state=42)
X_train.shape,Y_train.shape
# Out:
# ((37, 1), (37, 1))

# %%
X_test.shape,Y_test.shape
# Out:
# ((10, 1), (10, 1))

# %%
est.fit(X_train,Y_train)
print ("Coeffiecients Value:",est.coef_)
print ("Intercept Value:",est.intercept_)
# Out:
# Coeffiecients Value: [[815.14251301]]
# Intercept Value: [-1605560.19879643]

# %% [markdown]
# ## **REGRESSION EVALUATION METRICS**
#
#
# Here are two common evaluation metrics for regression problems:
#
# **Mean Squared Error** (MSE) is the mean of the squared errors:
#
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$
#
# **Root Mean Squared Error** (RMSE) is the square root of the mean of the squared errors:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$
#
#
# Comparing these metrics:
#
# - **MSE** is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# - **RMSE** is even more popular than MSE, because RMSE is interpretable in the "y" units.
#
# These two are called as **loss functions**, because we obviusoly try to minimize them to make our model fit better.

# %%
from sklearn import metrics
y_pred=est.predict(X_test)
results_df = pd.DataFrame({'Actual': Y_test.values.flatten(),'Predicted': y_pred.flatten(),'Difference':Y_test.values.flatten()-y_pred.flatten()})
(results_df)
# Out:
#          Actual     Predicted   Difference
# 0  17310.757750  22279.399682 -4968.641932
# 1  32755.176820  32061.109839   694.066981
# 2  16699.826680  21464.257169 -4764.430489
# 3  42676.468370  35321.679891  7354.788479
# 4  15755.820270  19833.972143 -4078.151873
# 5  32738.262900  29615.682300  3122.580600
# 6   9619.438377  10052.261987  -432.823610
# 7  16426.725480  15758.259578   668.465902
# 8   5576.514583   3531.121883  2045.392700
# 9  16369.317250  20649.114656 -4279.797406

# %%
print ("ROOT MEAN SQUARED ERROR (RMSE):",(metrics.mean_squared_error(y_pred,Y_test))**0.5)
print ("CO-EFFICIENT OF DETERMINATION (R^2):",metrics.r2_score(y_pred,Y_test))
# Out:
# ROOT MEAN SQUARED ERROR (RMSE): 3892.0194690913613
# CO-EFFICIENT OF DETERMINATION (R^2): 0.8233454160165982

# %% [markdown]
# ## **REGRESSION LINE**
#
# A regression line is a line that is fit to a set of data points in order to represent the relationship between two variables. The independent variable is plotted on the x-axis and the dependent variable is plotted on the y-axis. The slope of the regression line indicates the direction of the relationship between the two variables. A positive slope indicates that the dependent variable increases as the independent variable increases. A negative slope indicates that the dependent variable decreases as the independent variable increases.
#
#
# **Positive Linear Relationship:**
#
#
#
# > If, as "X" increases (goes to the right), "Y" also increases (goes up), then we have a positive linear relationship. It's like saying that when one thing gets bigger, the other thing also gets bigger. This suggests that there's a positive connection between the two.
#
#
#
# **Negative Linear Relationship:**
#
#
# > On the other hand, if as "X" increases, "Y" decreases (goes down), then we have a negative linear relationship. Here, it's as if when one thing gets bigger, the other thing becomes smaller. This shows that there's a negative connection between the two.

# %%
plt.figure(figsize=(8, 4))
plt.title('Scatter Plot with Linear Regression Line (Training)')

plt.scatter(X_train,Y_train)
plt.plot(X_train,est.predict(X_train),color='r')

# %%
plt.figure(figsize=(8, 4))
plt.title('Scatter Plot with Linear Regression Line (Test)')

plt.scatter(X_test,Y_test)
plt.plot(X_test,est.predict(X_test),color='r')

# %% [markdown]
# **Using the Regression Line to predict Future Per Capita Income of CANADA**

# %%
ex={"YEAR":[2024,2025,2029,2030,2040]}
topred=pd.DataFrame(ex)
predicted_per_capita_income = est.predict(topred)

predicted_per_capita_income = predicted_per_capita_income.reshape(-1)
predictions_df = pd.DataFrame({"Year": topred["YEAR"], "Predicted Per Capita Income": predicted_per_capita_income})
predictions_df
# Out:
#    Year  Predicted Per Capita Income
# 0  2024                 44288.247534
# 1  2025                 45103.390047
# 2  2029                 48363.960099
# 3  2030                 49179.102612
# 4  2040                 57330.527742
